# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# %matplotlib inline
# Out:
# /Users/rajegupt/anaconda3/lib/python3.6/site-packages/nltk/twitter/__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df = pd.read_csv("Amazon_Unlocked_Mobile.csv")

# %%
df.shape
# Out:
# (413840, 6)

# %%
df.head()
# Out:
#                                         Product Name Brand Name   Price  \
# 0  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 1  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 2  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 3  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
# 4  "CLEAR CLEAN ESN" Sprint EPIC 4G Galaxy SPH-D7...    Samsung  199.99
#
#    Rating                                            Reviews  Review Votes
# 0       5  I feel so LUCKY to have found this used (phone...           1.0
# 1       4  nice phone, nice up grade from my pantach revu...           0.0
# 2       5                                       Very pleased           0.0
# 3       4  It works good but it goes slow sometimes but i...           0.0
# 4       4  Great phone to replace my lost phone. The only...           0.0

# %%
df.head().plot.bar()

# %%
df.isnull().any()
# Out:
# Product Name    False
# Brand Name       True
# Price            True
# Rating          False
# Reviews          True
# Review Votes     True
# dtype: bool

# %%
df.isnull().values.sum()
# Out:
# 83462

# %%
df=df.dropna()
df.shape
# Out:
# (334335, 6)

# %%
print ('Total Unique Product Name:',len(df['Product Name'].unique()))
print ('Total Unique Brand Name:',len(df['Brand Name'].unique()))
print ('Total Unique Prices:',len(df['Price'].unique()))
print ('Total Unique Review Votes:',len(df['Review Votes'].unique()))
print (df['Rating'].unique())
# Out:
# Total Unique Product Name: 3675
# Total Unique Brand Name: 378
# Total Unique Prices: 1550
# Total Unique Review Votes: 234
# [5 4 1 2 3]

# %%
Customer_Ratings = Amazon_Meta_Data.groupby(
    'Brand Name'
    ).Rating.agg(
        ['count', 'min', 'max']
    ).sort_values(
        'count', ascending=False
    )
Customer_Ratings.head(15)

# %%
Customer_Ratings= df.groupby('Brand Name')['Rating'].agg(['count','min','max','mean','median']).sort_values('count',ascending=False)
Customer_Ratings.head(10)
# Out:
#             count  min  max      mean  median
# Brand Name
# Samsung     65747    1    5  3.962356     5.0
# BLU         63248    1    5  3.792262     4.0
# Apple       58186    1    5  3.924415     5.0
# LG          22417    1    5  3.841460     5.0
# BlackBerry  16872    1    5  3.741465     5.0
# Nokia       16806    1    5  3.819291     5.0
# Motorola    13417    1    5  3.812849     5.0
# HTC         12724    1    5  3.465420     4.0
# CNPGD       12613    1    5  3.106002     3.0
# OtterBox     7989    1    5  4.383778     5.0

# %%
Brand_products= df.groupby('Product Name')['Rating'].agg(['count','min','max','mean','median']).sort_values('count',ascending=False)
Brand_products.head(10)
# Out:
#                                                     count  min  max      mean  \
# Product Name
# Apple iPhone 4s 8GB Unlocked Smartphone w/ 8MP ...   1451    1    5  3.428670
# Apple MF259LL/A - iPhone 4s 8GB / 8MP Camera - ...   1241    1    5  3.374698
# BLU Studio 5.0 C HD Unlocked Cellphone, Black        1194    1    5  4.212730
# OtterBox Iphone 5/5S/SE Defender Case w/ Drop a...   1129    1    5  3.975199
# Motorola Moto E (1st Generation) - Black - 4 GB...   1127    1    5  4.418811
# Apple iPhone 5s 32GB (Silver) - AT&T                 1118    1    5  3.989267
# BLU Energy X Plus Smartphone - With 4000 mAh Su...   1111    1    5  3.792079
# Samsung Galaxy S Duos II S7582 DUAL SIM Factory...   1109    1    5  4.322813
# Samsung Galaxy S Duos II GT-S7582 Factory Unloc...   1108    1    5  4.297834
# Samsung Galaxy S Duos GT-S7562 GSM Unlocked Tou...   1096    1    5  3.604927
#
#                                                     median
# Product Name
# Apple iPhone 4s 8GB Unlocked Smartphone w/ 8MP ...     4.0
# Apple MF259LL/A - iPhone 4s 8GB / 8MP Camera - ...     4.0
# BLU Studio 5.0 C HD Unlocked Cellphone, Black          5.0
# OtterBox Iphone 5/5S/SE Defender Case w/ Drop a...     5.0
# 306399       4  Everything ok with the phone. It's a nice smar...
# 306400       5        Work with my simple mobile very good thanks
# 306401       1  Its a very fragile devices and burned internal...
# 306402       5  Excellent phone! Exactly what I expected of it...
# 306403       4  Good phone, maybe a little bit too big for me ...
# 306404       5  Excellent Product. Excellent Vendor. I truly r...
# 306394       5  Great product but LTE isn't that great. Hope i...
# 306406       1  DO NOT BUY This product unless you want to thr...
# 306407       5                                      EVERETHING OK
# 306409       1  Do NOT buy this phone. Purchased in January 20...
# 306419       5  Fast shipping. Perfect phone for form and bala...
# 306418       5                                          Excellent
# 306417       5  Love using this phone. Came unlocked as it say...
# 306416       5        Wow! Wait Wow! This a Samsung device, Wow !
# 306415       5                                 Excelente gracias.
# 306414       5  The phone is amazingly beautiful, in terms of ...
# 306408       1  I had this phone for about 8 months before the...
# 306413       5              Excellent phone! Arrived just in time
# 306411       4                 It is working pretty good for now.
# 306410       5           Excelent device and beautyfull designed.
# 306412       4  Great phone lovely features ,when I turn the p...
# 209689       5                                         Thank you!
# 209688       4  the phone is cover my expectatives, the qualit...
# 209687       2  I loved the phone and the style however it wou...
# 209686       1  Bought two of these as Christmas gifts. One of...
# 165302       5  These folks are good! Knowledgeable, helpful, ...
#
#         Review Votes
# 205952           0.0
# 206031           0.0
# 206030           0.0
# 206029           0.0
# 206028           0.0
# 206027           0.0
# 206026           0.0
# 206025           0.0
# 206024           0.0
# 206023           0.0
# 206022           0.0
# 206021           0.0
# 206020           0.0
# 206019           0.0
# 206018           0.0
# 206017           0.0
# 206016           0.0
# 206015           0.0
# 206014           0.0
# 206013           0.0
# 206012           1.0
# 206011           0.0
# 206010           0.0
# 206009           0.0
# 206008           0.0
# 206007           0.0
# 206006           0.0
# 206005           0.0
# 206004           0.0
# 206003           0.0
# ...              ...
# 306405           0.0
# 306396           0.0
# 306397           1.0
# 306398           1.0
# 306399           0.0
# 306400           0.0
# 306401           0.0
# 306402           1.0
# 306403           1.0
# 306404           0.0
# 306394           0.0
# 306406           0.0
# 306407           0.0
# 306409           1.0
# 306419           0.0
# 306418           0.0
# 306417           0.0
# 306416           0.0
# 306415           0.0
# 306414           0.0
# 306408           0.0
# 306413           1.0
# 306411           0.0
# 306410           0.0
# 306412           0.0
# 209689           0.0
# 209688           1.0
# 209687           1.0
# 209686           0.0
# 165302           0.0
#
# [334335 rows x 6 columns]

# %%
df.describe()
# Out:
#                Price         Rating   Review Votes
# count  334335.000000  334335.000000  334335.000000
# mean      222.585019       3.824888       1.474515
# std       283.139353       1.541203       9.217348
# min         1.730000       1.000000       0.000000
# 25%        75.410000       3.000000       0.000000
# 50%       139.000000       5.000000       0.000000
# 75%       264.100000       5.000000       1.000000
# max      2598.000000       5.000000     645.000000

# %%
plt.hist(df['Rating'])
# Out:
# (array([  57535.,       0.,   20068.,       0.,       0.,   26058.,
#               0.,   50421.,       0.,  180253.]),
#  array([ 1. ,  1.4,  1.8,  2.2,  2.6,  3. ,  3.4,  3.8,  4.2,  4.6,  5. ]),
#  <a list of 10 Patch objects>)

# %%
np.histogram(df['Price'],bins=4)
# Out:
# (array([320781,   8502,     12,   5040]),
#  array([  1.73000000e+00,   6.50797500e+02,   1.29986500e+03,
#           1.94893250e+03,   2.59800000e+03]))

# %%
#df.loc[df['Price'] <80, 'Price'] = 1

# %%
# To divide the continuous values into equal bins

#df['Price']=pd.qcut(df['Price'],4,labels=[1,2,3,4])

# %%
df['Price'].plot()

# %%
df[df['Price']<10]['Rating'].value_counts()
# Out:
# 5    2313
# 1     616
# 4     569
# 3     339
# 2     241
# Name: Rating, dtype: int64

# %%
df[df['Review Votes']==0].count()
# Out:
# Product Name    233064
# Brand Name      233064
# Price           233064
# Rating          233064
# Reviews         233064
# Review Votes    233064
# dtype: int64

# %%
df[df['Review Votes']==1].count()
# Out:
# Product Name    56930
# Brand Name      47959
# Price           55945
# Rating          56930
# Reviews         56923
# Review Votes    56930
# dtype: int64

# %%
df[df['Review Votes']>1].count()
# Out:
# Product Name    66171
# Brand Name      54811
# Price           65099
# Rating          66171
# Reviews         66125
# Review Votes    66171
# dtype: int64

# %%
print ('price null count',df['Price'].isnull().sum())
print ('Brand Name null count',df['Brand Name'].isnull().sum())
# Out:
# price null count 5933
# Brand Name null count 65171

# %%
df.dtypes
# Out:
# Product Name      object
# Brand Name        object
# Price           category
# Rating             int64
# Reviews           object
# Review Votes     float64
# dtype: object

# %%
enc_brand=pd.get_dummies(df['Brand Name'])
df= df.drop('Brand Name', axis=1)
df=df.join(enc_brand)

# %%
df.shape
# Out:
# (334335, 383)

# %%
target=df['Rating']
features=df.drop(['Product Name', 'Rating','Reviews'],axis=1)

# %%
from sklearn import preprocessing
scaler=preprocessing.StandardScaler().fit(features)
features_stand= scaler.transform(features)
#min_max_scaler = preprocessing.MinMaxScaler()
#features_norm= min_max_scaler.fit_transform(features)

# %%
print (features.shape)
features_norm
# Out:
# (334335, 380)
# array([[ 0.0763634 ,  0.00155039,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.0763634 ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.0763634 ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 0.03012784,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.03012784,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.03012784,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=4, random_state=10)
pca.fit(features_stand)
print (pca.explained_variance_ratio_)
features_PCA= pca.transform(features_stand)
# Out:
# [ 0.00350553  0.00288548  0.00278158  0.00265637]

# %%
features_PCA.shape
# Out:
# (334335, 4)

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(features_PCA, target, test_size=0.2, random_state=10)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import svm

clf_rf = RandomForestClassifier(random_state=10)
parameters={'n_estimators': [5,10,20], 'max_features':['sqrt','log2']}

clf_rf = GridSearchCV(clf_rf, parameters)


clf_lr= LogisticRegression(random_state=10)
clf_svm= svm.SVC(random_state=10)

# %%
rf_scores= cross_val_score(clf_rf,train_X, train_y,cv=10)
print ('RF score', rf_scores.mean())
# Out:
# RF score 0.543567118517

# %%
clf_lr.fit(train_X, train_y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=10, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
clf_lr.score(test_X, test_y)
# Out:
# 0.53887107580398164

# %% [markdown]
# ### Conclusion: With only three features (Brand, Price and Review Votes), model is giving 54% accuracy results. These results can be improved by adding more features, doing feature engineering like reducing the Brand Name categories etc.
#
# # Next Steps:
#     - NLP Model to leverage the Reviews
#     - Simplify the target by either averaging the price for each product name and use regression models
#     - Simplify the target into less categories such as Good and Bad for NLP classification
